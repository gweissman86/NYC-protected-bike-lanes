# %%
# %run nyc_bikemap.py
# Out:
# ...
# STATISTICAL SUMMARY: Median Income vs. Protected Bike Lanes
# ...
# Sample Size (Districts): 51
# Mean Median Income:       $89,153.43 (Std: $32,614.47)
# Mean Protected Lane %:    3.40% (Std: 4.44%)
# -----------------------------------------------------------------
# Pearson Correlation (r):  0.5872 (p-value: 0.0000)
# Spearman Rank Corr (r):  0.3064 (p-value: 0.0287)
# Linear Trend Line Equation: y = 0.000080 * x + -3.7267
# ...
