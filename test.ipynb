# %%
# %run nyc_bikemap.py

# %%
districts['
# Out:
# Index(['OID', 'AREA', 'DISTRICT', 'MEMBERS', 'LOCKED', 'NAME', 'ADJ_POPULA',
#        'ADJ_18_POP', 'ADJ_18_WHT', 'ADJ_18_BLK', 'ADJ_18_ASN', 'ADJ_H18_PO',
#        'ADJ_NH18_W', 'ADJ_NH18_B', 'ADJ_NH18_A', 'CVAP_TOT20', 'CVAP_ASN20',
#        'CVAP_BLK20', 'CVAP_WHT20', 'CVAP_HSP20', 'IDEAL_VALU', 'DEVIATION',
#        'F_DEVIATIO', 'POLSBY_POP', 'REOCK', 'F_ADJ_18_P', 'F_ADJ_18_W',
#        'F_ADJ_18_B', 'F_ADJ_18_A', 'F_ADJ_H18_', 'F_ADJ_NH18', 'F_ADJ_NH11',
#        'F_ADJ_NH12', 'F_CVAP_TOT', 'F_CVAP_ASN', 'F_CVAP_BLK', 'F_CVAP_WHT',
#        'F_CVAP_HSP', 'DISTRICT_L', 'geometry', 'Rank_x',
#        'City Council District',
#        'Percent of street miles with a protected bike lane', 'Rank_y',
#        'Representative', 'District Value', 'Median Income'],
#       dtype='str')
